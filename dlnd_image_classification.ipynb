# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:23, 7.29MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    y=np.array(x,dtype=float)
    y=(y-y.min())/(y.max()-y.min())
    # TODO: Implement Function
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    
    y=np.zeros((len(x),10))
    for idx in range(len(x)):
        for i in range(0,10):
            if x[idx] == i:
                y[idx,i] = 1
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    x = tf.placeholder(tf.float32,shape=[None, image_shape[0], image_shape[1], image_shape[2]],name='x')

    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    y = tf.placeholder(tf.float32, shape=[None, n_classes],name='y')
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep_prob=tf.placeholder(tf.float32,name='keep_prob')
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], x_tensor.get_shape().as_list()[3], conv_num_outputs],stddev=0.1))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    conv_layer = tf.nn.conv2d(x_tensor, weight, [1,conv_strides[0],conv_strides[1],1], padding='SAME')
    # Add bias
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    # Apply activation function
    conv_layer = tf.nn.relu(conv_layer)
    # maxpool
    pool_layer=tf.nn.max_pool(conv_layer,ksize=[1, pool_ksize[0],pool_ksize[1], 1], strides=[1, pool_strides[0], pool_strides[1], 1],padding='SAME')
    return pool_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()        
    dim = np.prod(shape[1:])            
    y = tf.reshape(x_tensor, [-1, dim])          
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """

    weights_con=tf.Variable(tf.random_normal([x_tensor.get_shape().as_list()[1],num_outputs],stddev=0.1))

    biases_con =tf.Variable(tf.random_normal([num_outputs]))

    out=tf.add(tf.matmul(x_tensor,weights_con),biases_con)
    out=tf.nn.relu(out)
    
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weights_out=tf.Variable(tf.random_normal([x_tensor.get_shape().as_list()[1],num_outputs],stddev=0.1))

    biases_out =tf.Variable(tf.random_normal([num_outputs]))

    out=tf.add(tf.matmul(x_tensor,weights_out),biases_out)
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    layer2=conv2d_maxpool(x, 60, [5,5], [2,2], [3,3], [2,2])
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    layer3=flatten(layer2)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    layer4=fully_conn(layer3,200)
    
    layer5=tf.nn.dropout(layer4, keep_prob, noise_shape=None, seed=None, name=None)
    
    layer6=fully_conn(layer5,100)
    
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    layer7=output(layer6,10)
    
    # TODO: return output
    return layer7


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x:feature_batch,y:label_batch,keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    print("Cost:")
    print(sess.run(cost, feed_dict={x: feature_batch, y: label_batch,keep_prob:1.0}))
    print("Accuracy:")
    print(sess.run(accuracy, feed_dict={x: valid_features, y: valid_labels,keep_prob:1.0}))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 128
keep_probability =0.7

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost:
# 1.97997
# Accuracy:
# 0.3776
# Epoch  2, CIFAR-10 Batch 1:  Cost:
# 1.71372
# Accuracy:
# 0.4388
# Epoch  3, CIFAR-10 Batch 1:  Cost:
# 1.43394
# Accuracy:
# 0.4882
# Epoch  4, CIFAR-10 Batch 1:  Cost:
# 1.30356
# Accuracy:
# 0.5118
# Epoch  5, CIFAR-10 Batch 1:  Cost:
# 1.12274
# Accuracy:
# 0.5334
# Epoch  6, CIFAR-10 Batch 1:  Cost:
# 1.0413
# Accuracy:
# 0.5464
# Epoch  7, CIFAR-10 Batch 1:  Cost:
# 0.925406
# Accuracy:
# 0.5512
# Epoch  8, CIFAR-10 Batch 1:  Cost:
# 0.806666
# Accuracy:
# 0.5584
# Epoch  9, CIFAR-10 Batch 1:  Cost:
# 0.725629
# Accuracy:
# 0.5634
# Epoch 10, CIFAR-10 Batch 1:  Cost:
# 0.659023
# Accuracy:
# 0.5718
# Epoch 11, CIFAR-10 Batch 1:  Cost:
# 0.582924
# Accuracy:
# 0.577
# Epoch 12, CIFAR-10 Batch 1:  Cost:
# 0.563793
# Accuracy:
# 0.5812
# Epoch 13, CIFAR-10 Batch 1:  Cost:
# 0.447057
# Accuracy:
# 0.5754
# Epoch 14, CIFAR-10 Batch 1:  Cost:
# 0.397973
# Accuracy:
# 0.5842
# Epoch 15, CIFAR-10 Batch 1:  Cost:
# 0.351374
# Accuracy:
# 0.5656
# Epoch 16, CIFAR-10 Batch 1:  Cost:
# 0.409818
# Accuracy:
# 0.5704
# Epoch 17, CIFAR-10 Batch 1:  Cost:
# 0.298125
# Accuracy:
# 0.5724
# Epoch 18, CIFAR-10 Batch 1:  Cost:
# 0.203877
# Accuracy:
# 0.5802
# Epoch 19, CIFAR-10 Batch 1:  Cost:
# 0.19499
# Accuracy:
# 0.5786
# Epoch 20, CIFAR-10 Batch 1:  Cost:
# 0.145939
# Accuracy:
# 0.576
# Epoch 21, CIFAR-10 Batch 1:  Cost:
# 0.156369
# Accuracy:
# 0.5674
# Epoch 22, CIFAR-10 Batch 1:  Cost:
# 0.145512
# Accuracy:
# 0.5778
# Epoch 23, CIFAR-10 Batch 1:  Cost:
# 0.100704
# Accuracy:
# 0.575
# Epoch 24, CIFAR-10 Batch 1:  Cost:
# 0.0803249
# Accuracy:
# 0.5834
# Epoch 25, CIFAR-10 Batch 1:  Cost:
# 0.0568685
# Accuracy:
# 0.5786
# Epoch 26, CIFAR-10 Batch 1:  Cost:
# 0.0655735
# Accuracy:
# 0.581
# Epoch 27, CIFAR-10 Batch 1:  Cost:
# 0.0680733
# Accuracy:
# 0.582
# Epoch 28, CIFAR-10 Batch 1:  Cost:
# 0.0514785
# Accuracy:
# 0.5898
# Epoch 29, CIFAR-10 Batch 1:  Cost:
# 0.0541624
# Accuracy:
# 0.592
# Epoch 30, CIFAR-10 Batch 1:  Cost:
# 0.039596
# Accuracy:
# 0.5938
# Epoch 31, CIFAR-10 Batch 1:  Cost:
# 0.0355685
# Accuracy:
# 0.5952
# Epoch 32, CIFAR-10 Batch 1:  Cost:
# 0.0273471
# Accuracy:
# 0.5928
# Epoch 33, CIFAR-10 Batch 1:  Cost:
# 0.0268582
# Accuracy:
# 0.5854
# Epoch 34, CIFAR-10 Batch 1:  Cost:
# 0.0268947
# Accuracy:
# 0.5706
# Epoch 35, CIFAR-10 Batch 1:  Cost:
# 0.0342539
# Accuracy:
# 0.582
# Epoch 36, CIFAR-10 Batch 1:  Cost:
# 0.0203016
# Accuracy:
# 0.5836
# Epoch 37, CIFAR-10 Batch 1:  Cost:
# 0.0135412
# Accuracy:
# 0.5694
# Epoch 38, CIFAR-10 Batch 1:  Cost:
# 0.0157715
# Accuracy:
# 0.5856
# Epoch 39, CIFAR-10 Batch 1:  Cost:
# 0.0134878
# Accuracy:
# 0.5848
# Epoch 40, CIFAR-10 Batch 1:  Cost:
# 0.0123278
# Accuracy:
# 0.5814
# Epoch 41, CIFAR-10 Batch 1:  Cost:
# 0.00776909
# Accuracy:
# 0.5932
# Epoch 42, CIFAR-10 Batch 1:  Cost:
# 0.00619831
# Accuracy:
# 0.5886
# Epoch 43, CIFAR-10 Batch 1:  Cost:
# 0.00800782
# Accuracy:
# 0.584
# Epoch 44, CIFAR-10 Batch 1:  Cost:
# 0.00845567
# Accuracy:
# 0.588
# Epoch 45, CIFAR-10 Batch 1:  Cost:
# 0.0107205
# Accuracy:
# 0.58
# Epoch 46, CIFAR-10 Batch 1:  Cost:
# 0.00492025
# Accuracy:
# 0.5932
# Epoch 47, CIFAR-10 Batch 1:  Cost:
# 0.00507231
# Accuracy:
# 0.5788
# Epoch 48, CIFAR-10 Batch 1:  Cost:
# 0.00325327
# Accuracy:
# 0.5832
# Epoch 49, CIFAR-10 Batch 1:  Cost:
# 0.00306436
# Accuracy:
# 0.5804
# Epoch 50, CIFAR-10 Batch 1:  Cost:
# 0.00459104
# Accuracy:
# 0.5796
# Epoch 51, CIFAR-10 Batch 1:  Cost:
# 0.00368696
# Accuracy:
# 0.5796
# Epoch 52, CIFAR-10 Batch 1:  Cost:
# 0.005274
# Accuracy:
# 0.5934
# Epoch 53, CIFAR-10 Batch 1:  Cost:
# 0.00464347
# Accuracy:
# 0.5774
# Epoch 54, CIFAR-10 Batch 1:  Cost:
# 0.00265344
# Accuracy:
# 0.5864
# Epoch 55, CIFAR-10 Batch 1:  Cost:
# 0.00252085
# Accuracy:
# 0.5874
# Epoch 56, CIFAR-10 Batch 1:  Cost:
# 0.00246923
# Accuracy:
# 0.5818
# Epoch 57, CIFAR-10 Batch 1:  Cost:
# 0.00671793
# Accuracy:
# 0.5732
# Epoch 58, CIFAR-10 Batch 1:  Cost:
# 0.00553931
# Accuracy:
# 0.5798
# Epoch 59, CIFAR-10 Batch 1:  Cost:
# 0.00457487
# Accuracy:
# 0.578
# Epoch 60, CIFAR-10 Batch 1:  Cost:
# 0.00300124
# Accuracy:
# 0.5844
# Epoch 61, CIFAR-10 Batch 1:  Cost:
# 0.00307495
# Accuracy:
# 0.5826
# Epoch 62, CIFAR-10 Batch 1:  Cost:
# 0.00202026
# Accuracy:
# 0.5832
# Epoch 63, CIFAR-10 Batch 1:  Cost:
# 0.00211588
# Accuracy:
# 0.5778
# Epoch 64, CIFAR-10 Batch 1:  Cost:
# 0.00526304
# Accuracy:
# 0.5842
# Epoch 65, CIFAR-10 Batch 1:  Cost:
# 0.00275716
# Accuracy:
# 0.5814
# Epoch 66, CIFAR-10 Batch 1:  Cost:
# 0.000976946
# Accuracy:
# 0.577
# Epoch 67, CIFAR-10 Batch 1:  Cost:
# 0.00317795
# Accuracy:
# 0.574
# Epoch 68, CIFAR-10 Batch 1:  Cost:
# 0.000672265
# Accuracy:
# 0.5824
# Epoch 69, CIFAR-10 Batch 1:  Cost:
# 0.0008659
# Accuracy:
# 0.5796
# Epoch 70, CIFAR-10 Batch 1:  Cost:
# 0.00200195
# Accuracy:
# 0.5704
# Epoch 71, CIFAR-10 Batch 1:  Cost:
# 0.00268501
# Accuracy:
# 0.577
# Epoch 72, CIFAR-10 Batch 1:  Cost:
# 0.00914247
# Accuracy:
# 0.5824
# Epoch 73, CIFAR-10 Batch 1:  Cost:
# 0.00157266
# Accuracy:
# 0.5806
# Epoch 74, CIFAR-10 Batch 1:  Cost:
# 0.00163435
# Accuracy:
# 0.5828
# Epoch 75, CIFAR-10 Batch 1:  Cost:
# 0.00156311
# Accuracy:
# 0.571
# Epoch 76, CIFAR-10 Batch 1:  Cost:
# 0.0014958
# Accuracy:
# 0.5676
# Epoch 77, CIFAR-10 Batch 1:  Cost:
# 0.000914554
# Accuracy:
# 0.5776
# Epoch 78, CIFAR-10 Batch 1:  Cost:
# 0.00128673
# Accuracy:
# 0.58
# Epoch 79, CIFAR-10 Batch 1:  Cost:
# 0.000509984
# Accuracy:
# 0.5824
# Epoch 80, CIFAR-10 Batch 1:  Cost:
# 0.000525923
# Accuracy:
# 0.5798
# Epoch 81, CIFAR-10 Batch 1:  Cost:
# 0.00284679
# Accuracy:
# 0.5728
# Epoch 82, CIFAR-10 Batch 1:  Cost:
# 0.000576673
# Accuracy:
# 0.5842
# Epoch 83, CIFAR-10 Batch 1:  Cost:
# 0.000387872
# Accuracy:
# 0.582
# Epoch 84, CIFAR-10 Batch 1:  Cost:
# 0.000733533
# Accuracy:
# 0.5792
# Epoch 85, CIFAR-10 Batch 1:  Cost:
# 0.000822795
# Accuracy:
# 0.5884
# Epoch 86, CIFAR-10 Batch 1:  Cost:
# 0.00054949
# Accuracy:
# 0.5818
# Epoch 87, CIFAR-10 Batch 1:  Cost:
# 0.00035372
# Accuracy:
# 0.5858
# Epoch 88, CIFAR-10 Batch 1:  Cost:
# 0.000431947
# Accuracy:
# 0.5942
# Epoch 89, CIFAR-10 Batch 1:  Cost:
# 0.000309962
# Accuracy:
# 0.5746
# Epoch 90, CIFAR-10 Batch 1:  Cost:
# 0.000969824
# Accuracy:
# 0.5776
# Epoch 91, CIFAR-10 Batch 1:  Cost:
# 0.00215952
# Accuracy:
# 0.5838
# Epoch 92, CIFAR-10 Batch 1:  Cost:
# 0.000225334
# Accuracy:
# 0.5854
# Epoch 93, CIFAR-10 Batch 1:  Cost:
# 0.00068248
# Accuracy:
# 0.5922
# Epoch 94, CIFAR-10 Batch 1:  Cost:
# 0.000979362
# Accuracy:
# 0.569
# Epoch 95, CIFAR-10 Batch 1:  Cost:
# 0.000370123
# Accuracy:
# 0.578
# Epoch 96, CIFAR-10 Batch 1:  Cost:
# 0.000325742
# Accuracy:
# 0.581
# Epoch 97, CIFAR-10 Batch 1:  Cost:
# 0.00013825
# Accuracy:
# 0.5936
# Epoch 98, CIFAR-10 Batch 1:  Cost:
# 0.000174608
# Accuracy:
# 0.5838
# Epoch 99, CIFAR-10 Batch 1:  Cost:
# 0.00106261
# Accuracy:
# 0.5782
# Epoch 100, CIFAR-10 Batch 1:  Cost:
# 0.000182433
# Accuracy:
# 0.5864

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost:
# 1.8929
# Accuracy:
# 0.38
# Epoch  1, CIFAR-10 Batch 2:  Cost:
# 1.57936
# Accuracy:
# 0.43
# Epoch  1, CIFAR-10 Batch 3:  Cost:
# 1.29627
# Accuracy:
# 0.4594
# Epoch  1, CIFAR-10 Batch 4:  Cost:
# 1.38424
# Accuracy:
# 0.4944
# Epoch  1, CIFAR-10 Batch 5:  Cost:
# 1.41282
# Accuracy:
# 0.5234
# Epoch  2, CIFAR-10 Batch 1:  Cost:
# 1.3625
# Accuracy:
# 0.5438
# Epoch  2, CIFAR-10 Batch 2:  Cost:
# 1.25565
# Accuracy:
# 0.5422
# Epoch  2, CIFAR-10 Batch 3:  Cost:
# 1.07676
# Accuracy:
# 0.5516
# Epoch  2, CIFAR-10 Batch 4:  Cost:
# 1.11047
# Accuracy:
# 0.5724
# Epoch  2, CIFAR-10 Batch 5:  Cost:
# 1.06881
# Accuracy:
# 0.5838
# Epoch  3, CIFAR-10 Batch 1:  Cost:
# 1.15732
# Accuracy:
# 0.5904
# Epoch  3, CIFAR-10 Batch 2:  Cost:
# 1.06459
# Accuracy:
# 0.5936
# Epoch  3, CIFAR-10 Batch 3:  Cost:
# 0.923043
# Accuracy:
# 0.5856
# Epoch  3, CIFAR-10 Batch 4:  Cost:
# 0.931262
# Accuracy:
# 0.6062
# Epoch  3, CIFAR-10 Batch 5:  Cost:
# 0.946914
# Accuracy:
# 0.6078
# Epoch  4, CIFAR-10 Batch 1:  Cost:
# 1.02652
# Accuracy:
# 0.6118
# Epoch  4, CIFAR-10 Batch 2:  Cost:
# 0.963616
# Accuracy:
# 0.6154
# Epoch  4, CIFAR-10 Batch 3:  Cost:
# 0.757301
# Accuracy:
# 0.6014
# Epoch  4, CIFAR-10 Batch 4:  Cost:
# 0.768024
# Accuracy:
# 0.6284
# Epoch  4, CIFAR-10 Batch 5:  Cost:
# 0.859977
# Accuracy:
# 0.6144
# Epoch  5, CIFAR-10 Batch 1:  Cost:
# 0.892596
# Accuracy:
# 0.6328
# Epoch  5, CIFAR-10 Batch 2:  Cost:
# 0.863556
# Accuracy:
# 0.628
# Epoch  5, CIFAR-10 Batch 3:  Cost:
# 0.671666
# Accuracy:
# 0.6264
# Epoch  5, CIFAR-10 Batch 4:  Cost:
# 0.737029
# Accuracy:
# 0.641
# Epoch  5, CIFAR-10 Batch 5:  Cost:
# 0.809132
# Accuracy:
# 0.6356
# Epoch  6, CIFAR-10 Batch 1:  Cost:
# 0.79639
# Accuracy:
# 0.6456
# Epoch  6, CIFAR-10 Batch 2:  Cost:
# 0.743514
# Accuracy:
# 0.6388
# Epoch  6, CIFAR-10 Batch 3:  Cost:
# 0.609489
# Accuracy:
# 0.6464
# Epoch  6, CIFAR-10 Batch 4:  Cost:
# 0.638605
# Accuracy:
# 0.6544
# Epoch  6, CIFAR-10 Batch 5:  Cost:
# 0.645708
# Accuracy:
# 0.646
# Epoch  7, CIFAR-10 Batch 1:  Cost:
# 0.689692
# Accuracy:
# 0.6634
# Epoch  7, CIFAR-10 Batch 2:  Cost:
# 0.634296
# Accuracy:
# 0.6544
# Epoch  7, CIFAR-10 Batch 3:  Cost:
# 0.451663
# Accuracy:
# 0.6594
# Epoch  7, CIFAR-10 Batch 4:  Cost:
# 0.490603
# Accuracy:
# 0.6682
# Epoch  7, CIFAR-10 Batch 5:  Cost:
# 0.558411
# Accuracy:
# 0.6584
# Epoch  8, CIFAR-10 Batch 1:  Cost:
# 0.631831
# Accuracy:
# 0.6652
# Epoch  8, CIFAR-10 Batch 2:  Cost:
# 0.573604
# Accuracy:
# 0.6588
# Epoch  8, CIFAR-10 Batch 3:  Cost:
# 0.364812
# Accuracy:
# 0.6558
# Epoch  8, CIFAR-10 Batch 4:  Cost:
# 0.517129
# Accuracy:
# 0.6666
# Epoch  8, CIFAR-10 Batch 5:  Cost:
# 0.52161
# Accuracy:
# 0.6534
# Epoch  9, CIFAR-10 Batch 1:  Cost:
# 0.585896
# Accuracy:
# 0.663
# Epoch  9, CIFAR-10 Batch 2:  Cost:
# 0.483803
# Accuracy:
# 0.6542
# Epoch  9, CIFAR-10 Batch 3:  Cost:
# 0.324022
# Accuracy:
# 0.6622
# Epoch  9, CIFAR-10 Batch 4:  Cost:
# 0.433408
# Accuracy:
# 0.6666
# Epoch  9, CIFAR-10 Batch 5:  Cost:
# 0.395558
# Accuracy:
# 0.6606
# Epoch 10, CIFAR-10 Batch 1:  Cost:
# 0.538936
# Accuracy:
# 0.6562
# Epoch 10, CIFAR-10 Batch 2:  Cost:
# 0.478086
# Accuracy:
# 0.6668
# Epoch 10, CIFAR-10 Batch 3:  Cost:
# 0.293025
# Accuracy:
# 0.6446
# Epoch 10, CIFAR-10 Batch 4:  Cost:
# 0.347467
# Accuracy:
# 0.6718
# Epoch 10, CIFAR-10 Batch 5:  Cost:
# 0.360644
# Accuracy:
# 0.669
# Epoch 11, CIFAR-10 Batch 1:  Cost:
# 0.476206
# Accuracy:
# 0.6754
# Epoch 11, CIFAR-10 Batch 2:  Cost:
# 0.389813
# Accuracy:
# 0.6726
# Epoch 11, CIFAR-10 Batch 3:  Cost:
# 0.244964
# Accuracy:
# 0.6626
# Epoch 11, CIFAR-10 Batch 4:  Cost:
# 0.356308
# Accuracy:
# 0.6714
# Epoch 11, CIFAR-10 Batch 5:  Cost:
# 0.306624
# Accuracy:
# 0.6502
# Epoch 12, CIFAR-10 Batch 1:  Cost:
# 0.396176
# Accuracy:
# 0.6684
# Epoch 12, CIFAR-10 Batch 2:  Cost:
# 0.29352
# Accuracy:
# 0.676
# Epoch 12, CIFAR-10 Batch 3:  Cost:
# 0.206917
# Accuracy:
# 0.6604
# Epoch 12, CIFAR-10 Batch 4:  Cost:
# 0.291837
# Accuracy:
# 0.6696
# Epoch 12, CIFAR-10 Batch 5:  Cost:
# 0.290892
# Accuracy:
# 0.665
# Epoch 13, CIFAR-10 Batch 1:  Cost:
# 0.327508
# Accuracy:
# 0.6638
# Epoch 13, CIFAR-10 Batch 2:  Cost:
# 0.276691
# Accuracy:
# 0.6734
# Epoch 13, CIFAR-10 Batch 3:  Cost:
# 0.183764
# Accuracy:
# 0.6622
# Epoch 13, CIFAR-10 Batch 4:  Cost:
# 0.256949
# Accuracy:
# 0.6802
# Epoch 13, CIFAR-10 Batch 5:  Cost:
# 0.233189
# Accuracy:
# 0.6734
# Epoch 14, CIFAR-10 Batch 1:  Cost:
# 0.284558
# Accuracy:
# 0.6702
# Epoch 14, CIFAR-10 Batch 2:  Cost:
# 0.203927
# Accuracy:
# 0.6814
# Epoch 14, CIFAR-10 Batch 3:  Cost:
# 0.162963
# Accuracy:
# 0.6764
# Epoch 14, CIFAR-10 Batch 4:  Cost:
# 0.241413
# Accuracy:
# 0.6732
# Epoch 14, CIFAR-10 Batch 5:  Cost:
# 0.232298
# Accuracy:
# 0.6514
# Epoch 15, CIFAR-10 Batch 1:  Cost:
# 0.24825
# Accuracy:
# 0.6782
# Epoch 15, CIFAR-10 Batch 2:  Cost:
# 0.219088
# Accuracy:
# 0.6712
# Epoch 15, CIFAR-10 Batch 3:  Cost:
# 0.163872
# Accuracy:
# 0.6756
# Epoch 15, CIFAR-10 Batch 4:  Cost:
# 0.227479
# Accuracy:
# 0.6608
# Epoch 15, CIFAR-10 Batch 5:  Cost:
# 0.185213
# Accuracy:
# 0.6666
# Epoch 16, CIFAR-10 Batch 1:  Cost:
# 0.181093
# Accuracy:
# 0.6686
# Epoch 16, CIFAR-10 Batch 2:  Cost:
# 0.179925
# Accuracy:
# 0.6686
# Epoch 16, CIFAR-10 Batch 3:  Cost:
# 0.131157
# Accuracy:
# 0.6736
# Epoch 16, CIFAR-10 Batch 4:  Cost:
# 0.249095
# Accuracy:
# 0.674
# Epoch 16, CIFAR-10 Batch 5:  Cost:
# 0.173409
# Accuracy:
# 0.6634
# Epoch 17, CIFAR-10 Batch 1:  Cost:
# 0.179348
# Accuracy:
# 0.6792
# Epoch 17, CIFAR-10 Batch 2:  Cost:
# 0.172651
# Accuracy:
# 0.6728
# Epoch 17, CIFAR-10 Batch 3:  Cost:
# 0.161258
# Accuracy:
# 0.6656
# Epoch 17, CIFAR-10 Batch 4:  Cost:
# 0.180091
# Accuracy:
# 0.6762
# Epoch 17, CIFAR-10 Batch 5:  Cost:
# 0.138206
# Accuracy:
# 0.6574
# Epoch 18, CIFAR-10 Batch 1:  Cost:
# 0.153894
# Accuracy:
# 0.6828
# Epoch 18, CIFAR-10 Batch 2:  Cost:
# 0.142291
# Accuracy:
# 0.6752
# Epoch 18, CIFAR-10 Batch 3:  Cost:
# 0.124151
# Accuracy:
# 0.6604
# Epoch 18, CIFAR-10 Batch 4:  Cost:
# 0.171172
# Accuracy:
# 0.6656
# Epoch 18, CIFAR-10 Batch 5:  Cost:
# 0.148211
# Accuracy:
# 0.6694
# Epoch 19, CIFAR-10 Batch 1:  Cost:
# 0.135465
# Accuracy:
# 0.679
# Epoch 19, CIFAR-10 Batch 2:  Cost:
# 0.0992034
# Accuracy:
# 0.6766
# Epoch 19, CIFAR-10 Batch 3:  Cost:
# 0.10583
# Accuracy:
# 0.682
# Epoch 19, CIFAR-10 Batch 4:  Cost:
# 0.158309
# Accuracy:
# 0.6586
# Epoch 19, CIFAR-10 Batch 5:  Cost:
# 0.129949
# Accuracy:
# 0.658
# Epoch 20, CIFAR-10 Batch 1:  Cost:
# 0.182424
# Accuracy:
# 0.6702
# Epoch 20, CIFAR-10 Batch 2:  Cost:
# 0.0857739
# Accuracy:
# 0.6824
# Epoch 20, CIFAR-10 Batch 3:  Cost:
# 0.103234
# Accuracy:
# 0.6786
# Epoch 20, CIFAR-10 Batch 4:  Cost:
# 0.119122
# Accuracy:
# 0.658
# Epoch 20, CIFAR-10 Batch 5:  Cost:
# 0.098762
# Accuracy:
# 0.6708
# Epoch 21, CIFAR-10 Batch 1:  Cost:
# 0.162822
# Accuracy:
# 0.6714
# Epoch 21, CIFAR-10 Batch 2:  Cost:
# 0.0856359
# Accuracy:
# 0.6768
# Epoch 21, CIFAR-10 Batch 3:  Cost:
# 0.0900118
# Accuracy:
# 0.6738
# Epoch 21, CIFAR-10 Batch 4:  Cost:
# 0.140351
# Accuracy:
# 0.6652
# Epoch 21, CIFAR-10 Batch 5:  Cost:
# 0.113329
# Accuracy:
# 0.6762
# Epoch 22, CIFAR-10 Batch 1:  Cost:
# 0.0963121
# Accuracy:
# 0.6758
# Epoch 22, CIFAR-10 Batch 2:  Cost:
# 0.0907488
# Accuracy:
# 0.6848
# Epoch 22, CIFAR-10 Batch 3:  Cost:
# 0.0798734
# Accuracy:
# 0.678
# Epoch 22, CIFAR-10 Batch 4:  Cost:
# 0.109707
# Accuracy:
# 0.6652
# Epoch 22, CIFAR-10 Batch 5:  Cost:
# 0.0793277
# Accuracy:
# 0.6818
# Epoch 23, CIFAR-10 Batch 1:  Cost:
# 0.0793074
# Accuracy:
# 0.6814
# Epoch 23, CIFAR-10 Batch 2:  Cost:
# 0.0853333
# Accuracy:
# 0.6818
# Epoch 23, CIFAR-10 Batch 3:  Cost:
# 0.0695784
# Accuracy:
# 0.6796
# Epoch 23, CIFAR-10 Batch 4:  Cost:
# 0.0642598
# Accuracy:
# 0.671
# Epoch 23, CIFAR-10 Batch 5:  Cost:
# 0.0561831
# Accuracy:
# 0.6836
# Epoch 24, CIFAR-10 Batch 1:  Cost:
# 0.0821013
# Accuracy:
# 0.6778
# Epoch 24, CIFAR-10 Batch 2:  Cost:
# 0.0520425
# Accuracy:
# 0.687
# Epoch 24, CIFAR-10 Batch 3:  Cost:
# 0.0746976
# Accuracy:
# 0.6794
# Epoch 24, CIFAR-10 Batch 4:  Cost:
# 0.0907684
# Accuracy:
# 0.6622
# Epoch 24, CIFAR-10 Batch 5:  Cost:
# 0.0609335
# Accuracy:
# 0.6806
# Epoch 25, CIFAR-10 Batch 1:  Cost:
# 0.0719132
# Accuracy:
# 0.6878
# Epoch 25, CIFAR-10 Batch 2:  Cost:
# 0.0472601
# Accuracy:
# 0.6804
# Epoch 25, CIFAR-10 Batch 3:  Cost:
# 0.0628937
# Accuracy:
# 0.679
# Epoch 25, CIFAR-10 Batch 4:  Cost:
# 0.0923169
# Accuracy:
# 0.671
# Epoch 25, CIFAR-10 Batch 5:  Cost:
# 0.0432324
# Accuracy:
# 0.6782
# Epoch 26, CIFAR-10 Batch 1:  Cost:
# 0.0859406
# Accuracy:
# 0.6718
# Epoch 26, CIFAR-10 Batch 2:  Cost:
# 0.0532915
# Accuracy:
# 0.6808
# Epoch 26, CIFAR-10 Batch 3:  Cost:
# 0.0492127
# Accuracy:
# 0.6708
# Epoch 26, CIFAR-10 Batch 4:  Cost:
# 0.0801454
# Accuracy:
# 0.6674
# Epoch 26, CIFAR-10 Batch 5:  Cost:
# 0.0354795
# Accuracy:
# 0.685
# Epoch 27, CIFAR-10 Batch 1:  Cost:
# 0.0524051
# Accuracy:
# 0.6812
# Epoch 27, CIFAR-10 Batch 2:  Cost:
# 0.0446897
# Accuracy:
# 0.6768
# Epoch 27, CIFAR-10 Batch 3:  Cost:
# 0.0348121
# Accuracy:
# 0.6868
# Epoch 27, CIFAR-10 Batch 4:  Cost:
# 0.0533469
# Accuracy:
# 0.6762
# Epoch 27, CIFAR-10 Batch 5:  Cost:
# 0.0387336
# Accuracy:
# 0.6828
# Epoch 28, CIFAR-10 Batch 1:  Cost:
# 0.0465612
# Accuracy:
# 0.6772
# Epoch 28, CIFAR-10 Batch 2:  Cost:
# 0.0548939
# Accuracy:
# 0.674
# Epoch 28, CIFAR-10 Batch 3:  Cost:
# 0.0425668
# Accuracy:
# 0.6782
# Epoch 28, CIFAR-10 Batch 4:  Cost:
# 0.061429
# Accuracy:
# 0.666
# Epoch 28, CIFAR-10 Batch 5:  Cost:
# 0.0352491
# Accuracy:
# 0.675
# Epoch 29, CIFAR-10 Batch 1:  Cost:
# 0.0560817
# Accuracy:
# 0.6794
# Epoch 29, CIFAR-10 Batch 2:  Cost:
# 0.0401977
# Accuracy:
# 0.6812
# Epoch 29, CIFAR-10 Batch 3:  Cost:
# 0.038275
# Accuracy:
# 0.6712
# Epoch 29, CIFAR-10 Batch 4:  Cost:
# 0.0457165
# Accuracy:
# 0.6688
# Epoch 29, CIFAR-10 Batch 5:  Cost:
# 0.0245348
# Accuracy:
# 0.6658
# Epoch 30, CIFAR-10 Batch 1:  Cost:
# 0.0520311
# Accuracy:
# 0.6784
# Epoch 30, CIFAR-10 Batch 2:  Cost:
# 0.020685
# Accuracy:
# 0.6812
# Epoch 30, CIFAR-10 Batch 3:  Cost:
# 0.0375588
# Accuracy:
# 0.6642
# Epoch 30, CIFAR-10 Batch 4:  Cost:
# 0.032203
# Accuracy:
# 0.6748
# Epoch 30, CIFAR-10 Batch 5:  Cost:
# 0.03309
# Accuracy:
# 0.673
# Epoch 31, CIFAR-10 Batch 1:  Cost:
# 0.0378726
# Accuracy:
# 0.6874
# Epoch 31, CIFAR-10 Batch 2:  Cost:
# 0.031679
# Accuracy:
# 0.6654
# Epoch 31, CIFAR-10 Batch 3:  Cost:
# 0.0301708
# Accuracy:
# 0.666
# Epoch 31, CIFAR-10 Batch 4:  Cost:
# 0.0443412
# Accuracy:
# 0.6662
# Epoch 31, CIFAR-10 Batch 5:  Cost:
# 0.0349646
# Accuracy:
# 0.6684
# Epoch 32, CIFAR-10 Batch 1:  Cost:
# 0.0396779
# Accuracy:
# 0.6786
# Epoch 32, CIFAR-10 Batch 2:  Cost:
# 0.0268479
# Accuracy:
# 0.6708
# Epoch 32, CIFAR-10 Batch 3:  Cost:
# 0.0357738
# Accuracy:
# 0.676
# Epoch 32, CIFAR-10 Batch 4:  Cost:
# 0.0273426
# Accuracy:
# 0.6748
# Epoch 32, CIFAR-10 Batch 5:  Cost:
# 0.039495
# Accuracy:
# 0.665
# Epoch 33, CIFAR-10 Batch 1:  Cost:
# 0.0326575
# Accuracy:
# 0.6748
# Epoch 33, CIFAR-10 Batch 2:  Cost:
# 0.0172294
# Accuracy:
# 0.6704
# Epoch 33, CIFAR-10 Batch 3:  Cost:
# 0.0252267
# Accuracy:
# 0.6668
# Epoch 33, CIFAR-10 Batch 4:  Cost:
# 0.0249681
# Accuracy:
# 0.6638
# Epoch 33, CIFAR-10 Batch 5:  Cost:
# 0.0191813
# Accuracy:
# 0.6786
# Epoch 34, CIFAR-10 Batch 1:  Cost:
# 0.0204153
# Accuracy:
# 0.6752
# Epoch 34, CIFAR-10 Batch 2:  Cost:
# 0.0252562
# Accuracy:
# 0.6718
# Epoch 34, CIFAR-10 Batch 3:  Cost:
# 0.0191562
# Accuracy:
# 0.6644
# Epoch 34, CIFAR-10 Batch 4:  Cost:
# 0.0308502
# Accuracy:
# 0.6718
# Epoch 34, CIFAR-10 Batch 5:  Cost:
# 0.0162409
# Accuracy:
# 0.6742
# Epoch 35, CIFAR-10 Batch 1:  Cost:
# 0.0329996
# Accuracy:
# 0.6692
# Epoch 35, CIFAR-10 Batch 2:  Cost:
# 0.0299452
# Accuracy:
# 0.6618
# Epoch 35, CIFAR-10 Batch 3:  Cost:
# 0.0167492
# Accuracy:
# 0.675
# Epoch 35, CIFAR-10 Batch 4:  Cost:
# 0.0165802
# Accuracy:
# 0.6716
# Epoch 35, CIFAR-10 Batch 5:  Cost:
# 0.0162407
# Accuracy:
# 0.6836
# Epoch 36, CIFAR-10 Batch 1:  Cost:
# 0.0184465
# Accuracy:
# 0.6764
# Epoch 36, CIFAR-10 Batch 2:  Cost:
# 0.0349236
# Accuracy:
# 0.6714
# Epoch 36, CIFAR-10 Batch 3:  Cost:
# 0.0354225
# Accuracy:
# 0.671
# Epoch 36, CIFAR-10 Batch 4:  Cost:
# 0.0165874
# Accuracy:
# 0.6728
# Epoch 36, CIFAR-10 Batch 5:  Cost:
# 0.0194158
# Accuracy:
# 0.6728
# Epoch 37, CIFAR-10 Batch 1:  Cost:
# 0.0222587
# Accuracy:
# 0.6788
# Epoch 37, CIFAR-10 Batch 2:  Cost:
# 0.0179226
# Accuracy:
# 0.6746
# Epoch 37, CIFAR-10 Batch 3:  Cost:
# 0.0193952
# Accuracy:
# 0.6736
# Epoch 37, CIFAR-10 Batch 4:  Cost:
# 0.0325371
# Accuracy:
# 0.6742
# Epoch 37, CIFAR-10 Batch 5:  Cost:
# 0.0124387
# Accuracy:
# 0.6802
# Epoch 38, CIFAR-10 Batch 1:  Cost:
# 0.0137709
# Accuracy:
# 0.6766
# Epoch 38, CIFAR-10 Batch 2:  Cost:
# 0.0282662
# Accuracy:
# 0.6688
# Epoch 38, CIFAR-10 Batch 3:  Cost:
# 0.0169356
# Accuracy:
# 0.6672
# Epoch 38, CIFAR-10 Batch 4:  Cost:
# 0.0249093
# Accuracy:
# 0.6654
# Epoch 38, CIFAR-10 Batch 5:  Cost:
# 0.0176912
# Accuracy:
# 0.669
# Epoch 39, CIFAR-10 Batch 1:  Cost:
# 0.0311143
# Accuracy:
# 0.6768
# Epoch 39, CIFAR-10 Batch 2:  Cost:
# 0.0195914
# Accuracy:
# 0.6632
# Epoch 39, CIFAR-10 Batch 3:  Cost:
# 0.0133088
# Accuracy:
# 0.6616
# Epoch 39, CIFAR-10 Batch 4:  Cost:
# 0.040415
# Accuracy:
# 0.672
# Epoch 39, CIFAR-10 Batch 5:  Cost:
# 0.0161493
# Accuracy:
# 0.6698
# Epoch 40, CIFAR-10 Batch 1:  Cost:
# 0.0157658
# Accuracy:
# 0.6828
# Epoch 40, CIFAR-10 Batch 2:  Cost:
# 0.0133173
# Accuracy:
# 0.66
# Epoch 40, CIFAR-10 Batch 3:  Cost:
# 0.0210833
# Accuracy:
# 0.6634
# Epoch 40, CIFAR-10 Batch 4:  Cost:
# 0.0158258
# Accuracy:
# 0.666
# Epoch 40, CIFAR-10 Batch 5:  Cost:
# 0.0178906
# Accuracy:
# 0.6696
# Epoch 41, CIFAR-10 Batch 1:  Cost:
# 0.017144
# Accuracy:
# 0.6644
# Epoch 41, CIFAR-10 Batch 2:  Cost:
# 0.0301063
# Accuracy:
# 0.6728
# Epoch 41, CIFAR-10 Batch 3:  Cost:
# 0.0277974
# Accuracy:
# 0.6602
# Epoch 41, CIFAR-10 Batch 4:  Cost:
# 0.0139717
# Accuracy:
# 0.6662
# Epoch 41, CIFAR-10 Batch 5:  Cost:
# 0.0299154
# Accuracy:
# 0.6728
# Epoch 42, CIFAR-10 Batch 1:  Cost:
# 0.0134776
# Accuracy:
# 0.6708
# Epoch 42, CIFAR-10 Batch 2:  Cost:
# 0.022831
# Accuracy:
# 0.6624
# Epoch 42, CIFAR-10 Batch 3:  Cost:
# 0.0241865
# Accuracy:
# 0.665
# Epoch 42, CIFAR-10 Batch 4:  Cost:
# 0.00936691
# Accuracy:
# 0.661
# Epoch 42, CIFAR-10 Batch 5:  Cost:
# 0.00693789
# Accuracy:
# 0.6804
# Epoch 43, CIFAR-10 Batch 1:  Cost:
# 0.0142447
# Accuracy:
# 0.6572
# Epoch 43, CIFAR-10 Batch 2:  Cost:
# 0.0189607
# Accuracy:
# 0.6684
# Epoch 43, CIFAR-10 Batch 3:  Cost:
# 0.0139697
# Accuracy:
# 0.66
# Epoch 43, CIFAR-10 Batch 4:  Cost:
# 0.0135644
# Accuracy:
# 0.6684
# Epoch 43, CIFAR-10 Batch 5:  Cost:
# 0.0087557
# Accuracy:
# 0.6702
# Epoch 44, CIFAR-10 Batch 1:  Cost:
# 0.015739
# Accuracy:
# 0.6728
# Epoch 44, CIFAR-10 Batch 2:  Cost:
# 0.0146822
# Accuracy:
# 0.6782
# Epoch 44, CIFAR-10 Batch 3:  Cost:
# 0.0113909
# Accuracy:
# 0.6712
# Epoch 44, CIFAR-10 Batch 4:  Cost:
# 0.0129982
# Accuracy:
# 0.6662
# Epoch 44, CIFAR-10 Batch 5:  Cost:
# 0.0106159
# Accuracy:
# 0.6748
# Epoch 45, CIFAR-10 Batch 1:  Cost:
# 0.0224989
# Accuracy:
# 0.6658
# Epoch 45, CIFAR-10 Batch 2:  Cost:
# 0.0125513
# Accuracy:
# 0.6696
# Epoch 45, CIFAR-10 Batch 3:  Cost:
# 0.0077124
# Accuracy:
# 0.676
# Epoch 45, CIFAR-10 Batch 4:  Cost:
# 0.0228631
# Accuracy:
# 0.6616
# Epoch 45, CIFAR-10 Batch 5:  Cost:
# 0.00972208
# Accuracy:
# 0.6736
# Epoch 46, CIFAR-10 Batch 1:  Cost:
# 0.0370823
# Accuracy:
# 0.6768
# Epoch 46, CIFAR-10 Batch 2:  Cost:
# 0.0189099
# Accuracy:
# 0.671
# Epoch 46, CIFAR-10 Batch 3:  Cost:
# 0.0111853
# Accuracy:
# 0.667
# Epoch 46, CIFAR-10 Batch 4:  Cost:
# 0.0105609
# Accuracy:
# 0.6604
# Epoch 46, CIFAR-10 Batch 5:  Cost:
# 0.0119456
# Accuracy:
# 0.6758
# Epoch 47, CIFAR-10 Batch 1:  Cost:
# 0.0115974
# Accuracy:
# 0.6698
# Epoch 47, CIFAR-10 Batch 2:  Cost:
# 0.0120016
# Accuracy:
# 0.6682
# Epoch 47, CIFAR-10 Batch 3:  Cost:
# 0.0129021
# Accuracy:
# 0.6532
# Epoch 47, CIFAR-10 Batch 4:  Cost:
# 0.0285776
# Accuracy:
# 0.668
# Epoch 47, CIFAR-10 Batch 5:  Cost:
# 0.0124357
# Accuracy:
# 0.677
# Epoch 48, CIFAR-10 Batch 1:  Cost:
# 0.0133941
# Accuracy:
# 0.671
# Epoch 48, CIFAR-10 Batch 2:  Cost:
# 0.0102152
# Accuracy:
# 0.6706
# Epoch 48, CIFAR-10 Batch 3:  Cost:
# 0.00718241
# Accuracy:
# 0.6654
# Epoch 48, CIFAR-10 Batch 4:  Cost:
# 0.0257301
# Accuracy:
# 0.651
# Epoch 48, CIFAR-10 Batch 5:  Cost:
# 0.00558415
# Accuracy:
# 0.6706
# Epoch 49, CIFAR-10 Batch 1:  Cost:
# 0.0129031
# Accuracy:
# 0.679
# Epoch 49, CIFAR-10 Batch 2:  Cost:
# 0.0130802
# Accuracy:
# 0.67
# Epoch 49, CIFAR-10 Batch 3:  Cost:
# 0.0104638
# Accuracy:
# 0.6688
# Epoch 49, CIFAR-10 Batch 4:  Cost:
# 0.0136875
# Accuracy:
# 0.6516
# Epoch 49, CIFAR-10 Batch 5:  Cost:
# 0.0106868
# Accuracy:
# 0.6724
# Epoch 50, CIFAR-10 Batch 1:  Cost:
# 0.016559
# Accuracy:
# 0.6624
# Epoch 50, CIFAR-10 Batch 2:  Cost:
# 0.0217029
# Accuracy:
# 0.6726
# Epoch 50, CIFAR-10 Batch 3:  Cost:
# 0.00789034
# Accuracy:
# 0.665
# Epoch 50, CIFAR-10 Batch 4:  Cost:
# 0.00931158
# Accuracy:
# 0.6514
# Epoch 50, CIFAR-10 Batch 5:  Cost:
# 0.00272815
# Accuracy:
# 0.672
# Epoch 51, CIFAR-10 Batch 1:  Cost:
# 0.0222624
# Accuracy:
# 0.6686
# Epoch 51, CIFAR-10 Batch 2:  Cost:
# 0.0101797
# Accuracy:
# 0.6668
# Epoch 51, CIFAR-10 Batch 3:  Cost:
# 0.00947082
# Accuracy:
# 0.6708
# Epoch 51, CIFAR-10 Batch 4:  Cost:
# 0.005889
# Accuracy:
# 0.6552
# Epoch 51, CIFAR-10 Batch 5:  Cost:
# 0.00410901
# Accuracy:
# 0.6662
# Epoch 52, CIFAR-10 Batch 1:  Cost:
# 0.0109736
# Accuracy:
# 0.6698
# Epoch 52, CIFAR-10 Batch 2:  Cost:
# 0.0153922
# Accuracy:
# 0.6636
# Epoch 52, CIFAR-10 Batch 3:  Cost:
# 0.00556887
# Accuracy:
# 0.6694
# Epoch 52, CIFAR-10 Batch 4:  Cost:
# 0.0189642
# Accuracy:
# 0.6514
# Epoch 52, CIFAR-10 Batch 5:  Cost:
# 0.00999794
# Accuracy:
# 0.6642
# Epoch 53, CIFAR-10 Batch 1:  Cost:
# 0.0127232
# Accuracy:
# 0.6692
# Epoch 53, CIFAR-10 Batch 2:  Cost:
# 0.0108829
# Accuracy:
# 0.671
# Epoch 53, CIFAR-10 Batch 3:  Cost:
# 0.0265713
# Accuracy:
# 0.6636
# Epoch 53, CIFAR-10 Batch 4:  Cost:
# 0.00832952
# Accuracy:
# 0.6492
# Epoch 53, CIFAR-10 Batch 5:  Cost:
# 0.00547635
# Accuracy:
# 0.6742
# Epoch 54, CIFAR-10 Batch 1:  Cost:
# 0.0114618
# Accuracy:
# 0.6764
# Epoch 54, CIFAR-10 Batch 2:  Cost:
# 0.011143
# Accuracy:
# 0.6728
# Epoch 54, CIFAR-10 Batch 3:  Cost:
# 0.0123943
# Accuracy:
# 0.6642
# Epoch 54, CIFAR-10 Batch 4:  Cost:
# 0.00899703
# Accuracy:
# 0.6598
# Epoch 54, CIFAR-10 Batch 5:  Cost:
# 0.00538588
# Accuracy:
# 0.662
# Epoch 55, CIFAR-10 Batch 1:  Cost:
# 0.015421
# Accuracy:
# 0.6632
# Epoch 55, CIFAR-10 Batch 2:  Cost:
# 0.0168002
# Accuracy:
# 0.6676
# Epoch 55, CIFAR-10 Batch 3:  Cost:
# 0.00969543
# Accuracy:
# 0.674
# Epoch 55, CIFAR-10 Batch 4:  Cost:
# 0.0118506
# Accuracy:
# 0.6604
# Epoch 55, CIFAR-10 Batch 5:  Cost:
# 0.00595007
# Accuracy:
# 0.6696
# Epoch 56, CIFAR-10 Batch 1:  Cost:
# 0.0175146
# Accuracy:
# 0.6638
# Epoch 56, CIFAR-10 Batch 2:  Cost:
# 0.0133316
# Accuracy:
# 0.6716
# Epoch 56, CIFAR-10 Batch 3:  Cost:
# 0.0028929
# Accuracy:
# 0.6652
# Epoch 56, CIFAR-10 Batch 4:  Cost:
# 0.00593471
# Accuracy:
# 0.6554
# Epoch 56, CIFAR-10 Batch 5:  Cost:
# 0.00425091
# Accuracy:
# 0.6654
# Epoch 57, CIFAR-10 Batch 1:  Cost:
# 0.0106389
# Accuracy:
# 0.662
# Epoch 57, CIFAR-10 Batch 2:  Cost:
# 0.00577234
# Accuracy:
# 0.6694
# Epoch 57, CIFAR-10 Batch 3:  Cost:
# 0.00932208
# Accuracy:
# 0.6558
# Epoch 57, CIFAR-10 Batch 4:  Cost:
# 0.0187565
# Accuracy:
# 0.6566
# Epoch 57, CIFAR-10 Batch 5:  Cost:
# 0.00393329
# Accuracy:
# 0.6734
# Epoch 58, CIFAR-10 Batch 1:  Cost:
# 0.0111341
# Accuracy:
# 0.6632
# Epoch 58, CIFAR-10 Batch 2:  Cost:
# 0.00275244
# Accuracy:
# 0.6724
# Epoch 58, CIFAR-10 Batch 3:  Cost:
# 0.00559932
# Accuracy:
# 0.6654
# Epoch 58, CIFAR-10 Batch 4:  Cost:
# 0.0143076
# Accuracy:
# 0.6546
# Epoch 58, CIFAR-10 Batch 5:  Cost:
# 0.0151188
# Accuracy:
# 0.6718
# Epoch 59, CIFAR-10 Batch 1:  Cost:
# 0.0095651
# Accuracy:
# 0.678
# Epoch 59, CIFAR-10 Batch 2:  Cost:
# 0.00626983
# Accuracy:
# 0.6704
# Epoch 59, CIFAR-10 Batch 3:  Cost:
# 0.00978115
# Accuracy:
# 0.6642
# Epoch 59, CIFAR-10 Batch 4:  Cost:
# 0.00441086
# Accuracy:
# 0.652
# Epoch 59, CIFAR-10 Batch 5:  Cost:
# 0.00891572
# Accuracy:
# 0.6652
# Epoch 60, CIFAR-10 Batch 1:  Cost:
# 0.00876887
# Accuracy:
# 0.6708
# Epoch 60, CIFAR-10 Batch 2:  Cost:
# 0.00333278
# Accuracy:
# 0.6686
# Epoch 60, CIFAR-10 Batch 3:  Cost:
# 0.00743491
# Accuracy:
# 0.6732
# Epoch 60, CIFAR-10 Batch 4:  Cost:
# 0.00758507
# Accuracy:
# 0.6638
# Epoch 60, CIFAR-10 Batch 5:  Cost:
# 0.00428406
# Accuracy:
# 0.669
# Epoch 61, CIFAR-10 Batch 1:  Cost:
# 0.00587838
# Accuracy:
# 0.6666
# Epoch 61, CIFAR-10 Batch 2:  Cost:
# 0.00598981
# Accuracy:
# 0.6646
# Epoch 61, CIFAR-10 Batch 3:  Cost:
# 0.0122572
# Accuracy:
# 0.6686
# Epoch 61, CIFAR-10 Batch 4:  Cost:
# 0.00538599
# Accuracy:
# 0.6706
# Epoch 61, CIFAR-10 Batch 5:  Cost:
# 0.00198302
# Accuracy:
# 0.6716
# Epoch 62, CIFAR-10 Batch 1:  Cost:
# 0.00844976
# Accuracy:
# 0.6712
# Epoch 62, CIFAR-10 Batch 2:  Cost:
# 0.00559971
# Accuracy:
# 0.6762
# Epoch 62, CIFAR-10 Batch 3:  Cost:
# 0.00710237
# Accuracy:
# 0.67
# Epoch 62, CIFAR-10 Batch 4:  Cost:
# 0.00728816
# Accuracy:
# 0.6532
# Epoch 62, CIFAR-10 Batch 5:  Cost:
# 0.00369434
# Accuracy:
# 0.6692
# Epoch 63, CIFAR-10 Batch 1:  Cost:
# 0.00503736
# Accuracy:
# 0.6752
# Epoch 63, CIFAR-10 Batch 2:  Cost:
# 0.00661379
# Accuracy:
# 0.6804
# Epoch 63, CIFAR-10 Batch 3:  Cost:
# 0.00374098
# Accuracy:
# 0.6652
# Epoch 63, CIFAR-10 Batch 4:  Cost:
# 0.00751944
# Accuracy:
# 0.6614
# Epoch 63, CIFAR-10 Batch 5:  Cost:
# 0.00347959
# Accuracy:
# 0.6672
# Epoch 64, CIFAR-10 Batch 1:  Cost:
# 0.00936094
# Accuracy:
# 0.6772
# Epoch 64, CIFAR-10 Batch 2:  Cost:
# 0.0121084
# Accuracy:
# 0.6664
# Epoch 64, CIFAR-10 Batch 3:  Cost:
# 0.00532077
# Accuracy:
# 0.6674
# Epoch 64, CIFAR-10 Batch 4:  Cost:
# 0.00493101
# Accuracy:
# 0.6536
# Epoch 64, CIFAR-10 Batch 5:  Cost:
# 0.00442286
# Accuracy:
# 0.6684
# Epoch 65, CIFAR-10 Batch 1:  Cost:
# 0.00701413
# Accuracy:
# 0.6768
# Epoch 65, CIFAR-10 Batch 2:  Cost:
# 0.00472406
# Accuracy:
# 0.6706
# Epoch 65, CIFAR-10 Batch 3:  Cost:
# 0.00778707
# Accuracy:
# 0.6728
# Epoch 65, CIFAR-10 Batch 4:  Cost:
# 0.00239863
# Accuracy:
# 0.668
# Epoch 65, CIFAR-10 Batch 5:  Cost:
# 0.00297686
# Accuracy:
# 0.669
# Epoch 66, CIFAR-10 Batch 1:  Cost:
# 0.00502475
# Accuracy:
# 0.671
# Epoch 66, CIFAR-10 Batch 2:  Cost:
# 0.00806519
# Accuracy:
# 0.6706
# Epoch 66, CIFAR-10 Batch 3:  Cost:
# 0.00451286
# Accuracy:
# 0.6718
# Epoch 66, CIFAR-10 Batch 4:  Cost:
# 0.00331292
# Accuracy:
# 0.6606
# Epoch 66, CIFAR-10 Batch 5:  Cost:
# 0.00271507
# Accuracy:
# 0.6736
# Epoch 67, CIFAR-10 Batch 1:  Cost:
# 0.00603662
# Accuracy:
# 0.6676
# Epoch 67, CIFAR-10 Batch 2:  Cost:
# 0.00720385
# Accuracy:
# 0.6624
# Epoch 67, CIFAR-10 Batch 3:  Cost:
# 0.00272596
# Accuracy:
# 0.6706
# Epoch 67, CIFAR-10 Batch 4:  Cost:
# 0.00321338
# Accuracy:
# 0.6614
# Epoch 67, CIFAR-10 Batch 5:  Cost:
# 0.00352726
# Accuracy:
# 0.6602
# Epoch 68, CIFAR-10 Batch 1:  Cost:
# 0.00924381
# Accuracy:
# 0.6682
# Epoch 68, CIFAR-10 Batch 2:  Cost:
# 0.00442258
# Accuracy:
# 0.673
# Epoch 68, CIFAR-10 Batch 3:  Cost:
# 0.00299357
# Accuracy:
# 0.6684
# Epoch 68, CIFAR-10 Batch 4:  Cost:
# 0.0142641
# Accuracy:
# 0.6594
# Epoch 68, CIFAR-10 Batch 5:  Cost:
# 0.00380307
# Accuracy:
# 0.6692
# Epoch 69, CIFAR-10 Batch 1:  Cost:
# 0.00455289
# Accuracy:
# 0.6692
# Epoch 69, CIFAR-10 Batch 2:  Cost:
# 0.0034748
# Accuracy:
# 0.666
# Epoch 69, CIFAR-10 Batch 3:  Cost:
# 0.0043462
# Accuracy:
# 0.6662
# Epoch 69, CIFAR-10 Batch 4:  Cost:
# 0.00289869
# Accuracy:
# 0.663
# Epoch 69, CIFAR-10 Batch 5:  Cost:
# 0.0014947
# Accuracy:
# 0.6762
# Epoch 70, CIFAR-10 Batch 1:  Cost:
# 0.00178559
# Accuracy:
# 0.6706
# Epoch 70, CIFAR-10 Batch 2:  Cost:
# 0.00331641
# Accuracy:
# 0.6764
# Epoch 70, CIFAR-10 Batch 3:  Cost:
# 0.00209012
# Accuracy:
# 0.667
# Epoch 70, CIFAR-10 Batch 4:  Cost:
# 0.00603918
# Accuracy:
# 0.6704
# Epoch 70, CIFAR-10 Batch 5:  Cost:
# 0.00297383
# Accuracy:
# 0.6668
# Epoch 71, CIFAR-10 Batch 1:  Cost:
# 0.00186337
# Accuracy:
# 0.6634
# Epoch 71, CIFAR-10 Batch 2:  Cost:
# 0.00586346
# Accuracy:
# 0.6678
# Epoch 71, CIFAR-10 Batch 3:  Cost:
# 0.00351409
# Accuracy:
# 0.677
# Epoch 71, CIFAR-10 Batch 4:  Cost:
# 0.00531574
# Accuracy:
# 0.664
# Epoch 71, CIFAR-10 Batch 5:  Cost:
# 0.00127301
# Accuracy:
# 0.6622
# Epoch 72, CIFAR-10 Batch 1:  Cost:
# 0.00272335
# Accuracy:
# 0.6732
# Epoch 72, CIFAR-10 Batch 2:  Cost:
# 0.0068336
# Accuracy:
# 0.673
# Epoch 72, CIFAR-10 Batch 3:  Cost:
# 0.000614045
# Accuracy:
# 0.672
# Epoch 72, CIFAR-10 Batch 4:  Cost:
# 0.00606861
# Accuracy:
# 0.6696
# Epoch 72, CIFAR-10 Batch 5:  Cost:
# 0.00140226
# Accuracy:
# 0.6724
# Epoch 73, CIFAR-10 Batch 1:  Cost:
# 0.00516258
# Accuracy:
# 0.6718
# Epoch 73, CIFAR-10 Batch 2:  Cost:
# 0.00201533
# Accuracy:
# 0.6718
# Epoch 73, CIFAR-10 Batch 3:  Cost:
# 0.00140409
# Accuracy:
# 0.6732
# Epoch 73, CIFAR-10 Batch 4:  Cost:
# 0.00695258
# Accuracy:
# 0.6496
# Epoch 73, CIFAR-10 Batch 5:  Cost:
# 0.00263215
# Accuracy:
# 0.6764
# Epoch 74, CIFAR-10 Batch 1:  Cost:
# 0.00485183
# Accuracy:
# 0.667
# Epoch 74, CIFAR-10 Batch 2:  Cost:
# 0.00378019
# Accuracy:
# 0.6614
# Epoch 74, CIFAR-10 Batch 3:  Cost:
# 0.00430681
# Accuracy:
# 0.6714
# Epoch 74, CIFAR-10 Batch 4:  Cost:
# 0.00517387
# Accuracy:
# 0.6748
# Epoch 74, CIFAR-10 Batch 5:  Cost:
# 0.0016873
# Accuracy:
# 0.6668
# Epoch 75, CIFAR-10 Batch 1:  Cost:
# 0.00546645
# Accuracy:
# 0.6684
# Epoch 75, CIFAR-10 Batch 2:  Cost:
# 0.00277884
# Accuracy:
# 0.6748
# Epoch 75, CIFAR-10 Batch 3:  Cost:
# 0.00671335
# Accuracy:
# 0.657
# Epoch 75, CIFAR-10 Batch 4:  Cost:
# 0.00358434
# Accuracy:
# 0.6598
# Epoch 75, CIFAR-10 Batch 5:  Cost:
# 0.000506897
# Accuracy:
# 0.6676
# Epoch 76, CIFAR-10 Batch 1:  Cost:
# 0.00416367
# Accuracy:
# 0.673
# Epoch 76, CIFAR-10 Batch 2:  Cost:
# 0.00519128
# Accuracy:
# 0.6594
# Epoch 76, CIFAR-10 Batch 3:  Cost:
# 0.0026021
# Accuracy:
# 0.6666
# Epoch 76, CIFAR-10 Batch 4:  Cost:
# 0.00555052
# Accuracy:
# 0.6608
# Epoch 76, CIFAR-10 Batch 5:  Cost:
# 0.00189422
# Accuracy:
# 0.6662
# Epoch 77, CIFAR-10 Batch 1:  Cost:
# 0.00370197
# Accuracy:
# 0.6704
# Epoch 77, CIFAR-10 Batch 2:  Cost:
# 0.00814082
# Accuracy:
# 0.6734
# Epoch 77, CIFAR-10 Batch 3:  Cost:
# 0.00926288
# Accuracy:
# 0.6696
# Epoch 77, CIFAR-10 Batch 4:  Cost:
# 0.00272195
# Accuracy:
# 0.6618
# Epoch 77, CIFAR-10 Batch 5:  Cost:
# 0.00673792
# Accuracy:
# 0.6682
# Epoch 78, CIFAR-10 Batch 1:  Cost:
# 0.0039019
# Accuracy:
# 0.676
# Epoch 78, CIFAR-10 Batch 2:  Cost:
# 0.00292527
# Accuracy:
# 0.665
# Epoch 78, CIFAR-10 Batch 3:  Cost:
# 0.00406204
# Accuracy:
# 0.6696
# Epoch 78, CIFAR-10 Batch 4:  Cost:
# 0.00435018
# Accuracy:
# 0.6552
# Epoch 78, CIFAR-10 Batch 5:  Cost:
# 0.00471268
# Accuracy:
# 0.6692
# Epoch 79, CIFAR-10 Batch 1:  Cost:
# 0.00188988
# Accuracy:
# 0.6742
# Epoch 79, CIFAR-10 Batch 2:  Cost:
# 0.00271844
# Accuracy:
# 0.6794
# Epoch 79, CIFAR-10 Batch 3:  Cost:
# 0.0066385
# Accuracy:
# 0.67
# Epoch 79, CIFAR-10 Batch 4:  Cost:
# 0.00256825
# Accuracy:
# 0.6572
# Epoch 79, CIFAR-10 Batch 5:  Cost:
# 0.00111083
# Accuracy:
# 0.672
# Epoch 80, CIFAR-10 Batch 1:  Cost:
# 0.00473342
# Accuracy:
# 0.6738
# Epoch 80, CIFAR-10 Batch 2:  Cost:
# 0.00283482
# Accuracy:
# 0.6704
# Epoch 80, CIFAR-10 Batch 3:  Cost:
# 0.00236845
# Accuracy:
# 0.6732
# Epoch 80, CIFAR-10 Batch 4:  Cost:
# 0.00174942
# Accuracy:
# 0.6676
# Epoch 80, CIFAR-10 Batch 5:  Cost:
# 0.0031118
# Accuracy:
# 0.673
# Epoch 81, CIFAR-10 Batch 1:  Cost:
# 0.0035301
# Accuracy:
# 0.6748
# Epoch 81, CIFAR-10 Batch 2:  Cost:
# 0.00356407
# Accuracy:
# 0.674
# Epoch 81, CIFAR-10 Batch 3:  Cost:
# 0.00453182
# Accuracy:
# 0.665
# Epoch 81, CIFAR-10 Batch 4:  Cost:
# 0.00106597
# Accuracy:
# 0.666
# Epoch 81, CIFAR-10 Batch 5:  Cost:
# 0.00283967
# Accuracy:
# 0.674
# Epoch 82, CIFAR-10 Batch 1:  Cost:
# 0.00718707
# Accuracy:
# 0.674
# Epoch 82, CIFAR-10 Batch 2:  Cost:
# 0.00411376
# Accuracy:
# 0.6688
# Epoch 82, CIFAR-10 Batch 3:  Cost:
# 0.00873052
# Accuracy:
# 0.6726
# Epoch 82, CIFAR-10 Batch 4:  Cost:
# 0.00355316
# Accuracy:
# 0.6554
# Epoch 82, CIFAR-10 Batch 5:  Cost:
# 0.00164744
# Accuracy:
# 0.675
# Epoch 83, CIFAR-10 Batch 1:  Cost:
# 0.00592772
# Accuracy:
# 0.672
# Epoch 83, CIFAR-10 Batch 2:  Cost:
# 0.0014847
# Accuracy:
# 0.6644
# Epoch 83, CIFAR-10 Batch 3:  Cost:
# 0.00173116
# Accuracy:
# 0.6698
# Epoch 83, CIFAR-10 Batch 4:  Cost:
# 0.0136181
# Accuracy:
# 0.6638
# Epoch 83, CIFAR-10 Batch 5:  Cost:
# 0.00691947
# Accuracy:
# 0.672
# Epoch 84, CIFAR-10 Batch 1:  Cost:
# 0.00427025
# Accuracy:
# 0.6746
# Epoch 84, CIFAR-10 Batch 2:  Cost:
# 0.00666773
# Accuracy:
# 0.6708
# Epoch 84, CIFAR-10 Batch 3:  Cost:
# 0.00361598
# Accuracy:
# 0.6696
# Epoch 84, CIFAR-10 Batch 4:  Cost:
# 0.00333694
# Accuracy:
# 0.6584
# Epoch 84, CIFAR-10 Batch 5:  Cost:
# 0.00215426
# Accuracy:
# 0.6668
# Epoch 85, CIFAR-10 Batch 1:  Cost:
# 0.00484872
# Accuracy:
# 0.6668
# Epoch 85, CIFAR-10 Batch 2:  Cost:
# 0.00393582
# Accuracy:
# 0.6762
# Epoch 85, CIFAR-10 Batch 3:  Cost:
# 0.00226037
# Accuracy:
# 0.6606
# Epoch 85, CIFAR-10 Batch 4:  Cost:
# 0.00840933
# Accuracy:
# 0.6536
# Epoch 85, CIFAR-10 Batch 5:  Cost:
# 0.00259133
# Accuracy:
# 0.6734
# Epoch 86, CIFAR-10 Batch 1:  Cost:
# 0.00267154
# Accuracy:
# 0.6678
# Epoch 86, CIFAR-10 Batch 2:  Cost:
# 0.0047625
# Accuracy:
# 0.6734
# Epoch 86, CIFAR-10 Batch 3:  Cost:
# 0.00264821
# Accuracy:
# 0.6712
# Epoch 86, CIFAR-10 Batch 4:  Cost:
# 0.00744108
# Accuracy:
# 0.6584
# Epoch 86, CIFAR-10 Batch 5:  Cost:
# 0.00168189
# Accuracy:
# 0.6738
# Epoch 87, CIFAR-10 Batch 1:  Cost:
# 0.0108414
# Accuracy:
# 0.671
# Epoch 87, CIFAR-10 Batch 2:  Cost:
# 0.0040317
# Accuracy:
# 0.6648
# Epoch 87, CIFAR-10 Batch 3:  Cost:
# 0.00419033
# Accuracy:
# 0.6648
# Epoch 87, CIFAR-10 Batch 4:  Cost:
# 0.00462658
# Accuracy:
# 0.661
# Epoch 87, CIFAR-10 Batch 5:  Cost:
# 0.0020533
# Accuracy:
# 0.6716
# Epoch 88, CIFAR-10 Batch 1:  Cost:
# 0.00397982
# Accuracy:
# 0.6686
# Epoch 88, CIFAR-10 Batch 2:  Cost:
# 0.00624483
# Accuracy:
# 0.6722
# Epoch 88, CIFAR-10 Batch 3:  Cost:
# 0.00682247
# Accuracy:
# 0.6692
# Epoch 88, CIFAR-10 Batch 4:  Cost:
# 0.00713217
# Accuracy:
# 0.6514
# Epoch 88, CIFAR-10 Batch 5:  Cost:
# 0.00226093
# Accuracy:
# 0.6692
# Epoch 89, CIFAR-10 Batch 1:  Cost:
# 0.00374436
# Accuracy:
# 0.6712
# Epoch 89, CIFAR-10 Batch 2:  Cost:
# 0.0045093
# Accuracy:
# 0.6726
# Epoch 89, CIFAR-10 Batch 3:  Cost:
# 0.00186047
# Accuracy:
# 0.6714
# Epoch 89, CIFAR-10 Batch 4:  Cost:
# 0.0041721
# Accuracy:
# 0.6648
# Epoch 89, CIFAR-10 Batch 5:  Cost:
# 0.00102426
# Accuracy:
# 0.6778
# Epoch 90, CIFAR-10 Batch 1:  Cost:
# 0.00239268
# Accuracy:
# 0.6792
# Epoch 90, CIFAR-10 Batch 2:  Cost:
# 0.00286221
# Accuracy:
# 0.6676
# Epoch 90, CIFAR-10 Batch 3:  Cost:
# 0.00275182
# Accuracy:
# 0.6732
# Epoch 90, CIFAR-10 Batch 4:  Cost:
# 0.0027148
# Accuracy:
# 0.6618
# Epoch 90, CIFAR-10 Batch 5:  Cost:
# 0.0012081
# Accuracy:
# 0.6732
# Epoch 91, CIFAR-10 Batch 1:  Cost:
# 0.00257083
# Accuracy:
# 0.685
# Epoch 91, CIFAR-10 Batch 2:  Cost:
# 0.00402232
# Accuracy:
# 0.6804
# Epoch 91, CIFAR-10 Batch 3:  Cost:
# 0.00258232
# Accuracy:
# 0.665
# Epoch 91, CIFAR-10 Batch 4:  Cost:
# 0.00103358
# Accuracy:
# 0.6646
# Epoch 91, CIFAR-10 Batch 5:  Cost:
# 0.00158181
# Accuracy:
# 0.6734
# Epoch 92, CIFAR-10 Batch 1:  Cost:
# 0.00826917
# Accuracy:
# 0.6666
# Epoch 92, CIFAR-10 Batch 2:  Cost:
# 0.0034465
# Accuracy:
# 0.6658
# Epoch 92, CIFAR-10 Batch 3:  Cost:
# 0.00801977
# Accuracy:
# 0.672
# Epoch 92, CIFAR-10 Batch 4:  Cost:
# 0.00210379
# Accuracy:
# 0.6556
# Epoch 92, CIFAR-10 Batch 5:  Cost:
# 0.00115603
# Accuracy:
# 0.6766
# Epoch 93, CIFAR-10 Batch 1:  Cost:
# 0.00130806
# Accuracy:
# 0.6644
# Epoch 93, CIFAR-10 Batch 2:  Cost:
# 0.00272784
# Accuracy:
# 0.6668
# Epoch 93, CIFAR-10 Batch 3:  Cost:
# 0.00290978
# Accuracy:
# 0.6654
# Epoch 93, CIFAR-10 Batch 4:  Cost:
# 0.00158762
# Accuracy:
# 0.6638
# Epoch 93, CIFAR-10 Batch 5:  Cost:
# 0.000622084
# Accuracy:
# 0.6716
# Epoch 94, CIFAR-10 Batch 1:  Cost:
# 0.00169554
# Accuracy:
# 0.675
# Epoch 94, CIFAR-10 Batch 2:  Cost:
# 0.00218107
# Accuracy:
# 0.6696
# Epoch 94, CIFAR-10 Batch 3:  Cost:
# 0.00846523
# Accuracy:
# 0.6678
# Epoch 94, CIFAR-10 Batch 4:  Cost:
# 0.00336197
# Accuracy:
# 0.6576
# Epoch 94, CIFAR-10 Batch 5:  Cost:
# 0.00210929
# Accuracy:
# 0.6774
# Epoch 95, CIFAR-10 Batch 1:  Cost:
# 0.00587227
# Accuracy:
# 0.6682
# Epoch 95, CIFAR-10 Batch 2:  Cost:
# 0.0059691
# Accuracy:
# 0.6632
# Epoch 95, CIFAR-10 Batch 3:  Cost:
# 0.00103972
# Accuracy:
# 0.6714
# Epoch 95, CIFAR-10 Batch 4:  Cost:
# 0.0034032
# Accuracy:
# 0.661
# Epoch 95, CIFAR-10 Batch 5:  Cost:
# 0.000735627
# Accuracy:
# 0.6724
# Epoch 96, CIFAR-10 Batch 1:  Cost:
# 0.0016077
# Accuracy:
# 0.6734
# Epoch 96, CIFAR-10 Batch 2:  Cost:
# 0.00373714
# Accuracy:
# 0.6704
# Epoch 96, CIFAR-10 Batch 3:  Cost:
# 0.00353526
# Accuracy:
# 0.6622
# Epoch 96, CIFAR-10 Batch 4:  Cost:
# 0.000703413
# Accuracy:
# 0.659
# Epoch 96, CIFAR-10 Batch 5:  Cost:
# 0.00103812
# Accuracy:
# 0.6708
# Epoch 97, CIFAR-10 Batch 1:  Cost:
# 0.00146023
# Accuracy:
# 0.6718
# Epoch 97, CIFAR-10 Batch 2:  Cost:
# 0.00217185
# Accuracy:
# 0.67
# Epoch 97, CIFAR-10 Batch 3:  Cost:
# 0.000843642
# Accuracy:
# 0.671
# Epoch 97, CIFAR-10 Batch 4:  Cost:
# 0.00203054
# Accuracy:
# 0.6528
# Epoch 97, CIFAR-10 Batch 5:  Cost:
# 0.00110265
# Accuracy:
# 0.6688
# Epoch 98, CIFAR-10 Batch 1:  Cost:
# 0.00147871
# Accuracy:
# 0.6632
# Epoch 98, CIFAR-10 Batch 2:  Cost:
# 0.001254
# Accuracy:
# 0.6672
# Epoch 98, CIFAR-10 Batch 3:  Cost:
# 0.000539408
# Accuracy:
# 0.6688
# Epoch 98, CIFAR-10 Batch 4:  Cost:
# 0.00322948
# Accuracy:
# 0.6594
# Epoch 98, CIFAR-10 Batch 5:  Cost:
# 0.000989456
# Accuracy:
# 0.6736
# Epoch 99, CIFAR-10 Batch 1:  Cost:
# 0.00075827
# Accuracy:
# 0.6712
# Epoch 99, CIFAR-10 Batch 2:  Cost:
# 0.0023084
# Accuracy:
# 0.6596
# Epoch 99, CIFAR-10 Batch 3:  Cost:
# 0.0017438
# Accuracy:
# 0.672
# Epoch 99, CIFAR-10 Batch 4:  Cost:
# 0.00351972
# Accuracy:
# 0.6556
# Epoch 99, CIFAR-10 Batch 5:  Cost:
# 0.00116808
# Accuracy:
# 0.67
# Epoch 100, CIFAR-10 Batch 1:  Cost:
# 0.00253067
# Accuracy:
# 0.6748
# Epoch 100, CIFAR-10 Batch 2:  Cost:
# 0.00146507
# Accuracy:
# 0.674
# Epoch 100, CIFAR-10 Batch 3:  Cost:
# 0.000377889
# Accuracy:
# 0.6668
# Epoch 100, CIFAR-10 Batch 4:  Cost:
# 0.00161858
# Accuracy:
# 0.6638
# Epoch 100, CIFAR-10 Batch 5:  Cost:
# 0.000618428
# Accuracy:
# 0.6778

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6720727848101266

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
